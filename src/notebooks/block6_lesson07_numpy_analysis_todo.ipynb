# %% [markdown]
# # Блок 6. Погружение в Python и анализ данных
# ## Занятие 7. NumPy для анализа данных
#
# ### Цель занятия
#
# После изучения базовых возможностей NumPy переходим к его использованию для анализа данных.
#
# Сегодня изучаем:
#
# - фильтрацию данных;
# - логические маски;
# - поиск аномалий;
# - работу с финансовыми данными;
# - работу со спортивными данными;
# - подготовку данных для машинного обучения.
#
# ### Практическое значение
#
# NumPy используется для быстрой обработки миллионов числовых значений.
#
# Типовые задачи:
#
# - поиск выбросов;
# - поиск лучших результатов;
# - поиск проблемных значений;
# - подготовка данных для моделей.
#
# ### Связь с дипломом
#
# Методы занятия будут использоваться в:
#
# - анализе продаж;
# - анализе недвижимости;
# - анализе финансов;
# - анализе тренировок;
# - ML-проектах.
#
#
# Сначала изучите SOLVED-ноутбук, затем выполните TODO самостоятельно.

# %% [markdown]
# ## Ячейка 1. Подключение NumPy
#
# ### Алгоритм
#
# Импортируем библиотеку и проверяем версию.

# %%
# TODO: выполните задание ячейки 1

# %% [markdown]
# ## Ячейка 2. Финансовый датасет
#
# ### Алгоритм
#
# Создаем массив дневной прибыли.

# %%
# TODO: выполните задание ячейки 2

# %% [markdown]
# ## Ячейка 3. Логические маски
#
# ### Алгоритм
#
# Находим прибыль больше 150.

# %%
# TODO: выполните задание ячейки 3

# %% [markdown]
# ## Ячейка 4. Поиск аномалий
#
# ### Алгоритм
#
# Находим прибыль ниже 100.

# %%
# TODO: выполните задание ячейки 4

# %% [markdown]
# ## Ячейка 5. Статистика
#
# ### Алгоритм
#
# Считаем среднее и стандартное отклонение.

# %%
# TODO: выполните задание ячейки 5

# %% [markdown]
# ## Ячейка 6. Датасет тренировок
#
# ### Алгоритм
#
# Создаем данные по калориям.

# %%
# TODO: выполните задание ячейки 6

# %% [markdown]
# ## Ячейка 7. Поиск лучших тренировок
#
# ### Алгоритм
#
# Выбираем тренировки выше среднего.

# %%
# TODO: выполните задание ячейки 7

# %% [markdown]
# ## Ячейка 8. Нормализация
#
# ### Алгоритм
#
# Нормализуем данные тренировок.

# %%
# TODO: выполните задание ячейки 8

# %% [markdown]
# ## Ячейка 9. Функция поиска аномалий
#
# ### Алгоритм
#
# Создаем функцию для поиска выбросов.

# %%
# TODO: выполните задание ячейки 9

# %% [markdown]
# ## Ячейка 10. Мини-проект
#
# ### Алгоритм
#
# Анализируем продажи через NumPy.

# %%
# TODO: выполните задание ячейки 10
